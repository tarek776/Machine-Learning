# %% [markdown]
# <a href="https://colab.research.google.com/github/tarek776/Machine-Learning/blob/main/Copy_of_Diabetes_project_robotech_alexEgypt_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('diabetes.csv')
print(file)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier

# %%
l=file.dropna()
print(l.tail())
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
x=file.drop('Outcome',axis=1)
y=file['Outcome']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=45)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
Accuracy=print("Accuracy:",accuracy_score(y_test,y_pred))
ConfusionMatrix=print("ConfusionMatrix:",confusion_matrix(y_test,y_pred))
ClassificationReport=print("ClassificationReport:",classification_report(y_test,y_pred))
# Out:
# Accuracy: 0.765625
# ConfusionMatrix: [[214  36]
#  [ 54  80]]
# ClassificationReport:               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       250
#            1       0.69      0.60      0.64       134
#
#     accuracy                           0.77       384
#    macro avg       0.74      0.73      0.73       384
# weighted avg       0.76      0.77      0.76       384

# %%
k=file[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
t=file['Outcome']

# %%
regression=linear_model.LinearRegression()
regression.fit(k,t)
predict=regression.predict([[7500,6200,2000,1400,1700,2500,4700,6000]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(predict)
# Out:
# [926.39089851]

# %%
y = np.array([
    file["Glucose"].mean(),
    file["Insulin"].mean(),
    file["Pregnancies"].mean(),
    file["Age"].mean(),
    file["BloodPressure"].mean(),
    file["BMI"].mean(),
    file["DiabetesPedigreeFunction"].mean(),
    file["SkinThickness"].mean()
])
mylabels = [
    "Glucose", "Insulin", "Pregnancies", "Age", "BloodPressure", "BMI", "DiabetesPedigreeFunction", "SkinThickness"
]
myexplode = [0.2, 0.1, 0.3, 0.5, 0.6, 0.4, 0.7, 0.1]  # Emphasize the first slice

plt.pie(y, labels=mylabels, explode=myexplode, autopct="%1.1f%%")
plt.title("Feature Distribution")
plt.show()

# %%
plt.figure(figsize=(15, 10))

xpoints=np.array(file.SkinThickness)
plt.subplot(2,3,1)
plt.plot(xpoints)
plt.title("SkinThickness")

ypoints=np.array(file.Insulin)
plt.subplot(2,3,2)
plt.plot(ypoints,color="green")
plt.title("Insuline")

zpoints=np.array(file.Pregnancies)
plt.subplot(2,3,3)
plt.plot(zpoints,color="pink")
plt.title("Pregnancies")

lpoints=np.array(file.Glucose)
plt.subplot(2,3,4)
plt.plot(lpoints,color="red")
plt.title("Glucose")

npoints=np.array(file.BMI )
plt.subplot(2,3,5)
plt.plot(npoints,color="yellow")
plt.title("BMI")

mpoints=np.array(file.BloodPressure)
plt.subplot(2,3,6)
plt.plot(mpoints,color="black")
plt.title("BloodPressure")

plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 10))

bpoints=np.array(file.DiabetesPedigreeFunction)
plt.subplot(2,4,1)
plt.plot(bpoints,color="orange")
plt.title("DiabetesPedigreeFunction")

kpoints=np.array(file.Age)
plt.subplot(2,4,2)
plt.plot(kpoints,color="blue")
plt.title("Age")

upoints=np.array(file.Outcome)
plt.subplot(2,4,3)
plt.plot(upoints,color="yellow")
plt.title("Outcome")

plt.tight_layout()
plt.show()

# %%
pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 51.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 70.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 87.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 80.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.7 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
from sklearn.preprocessing import LabelEncoder

# %%
@st.cache_data
def load_and_preprocess_data():
    file=pd.read_csv('diabetes.csv')
    LE=LabelEncoder()
    for col in file.select_dtypes(include=['object']).columns:
        file[col]=LE.fit_transform(file[col])
    return file
# Out:
# 2025-01-25 13:37:13.521 No runtime found, using MemoryCacheStorageManager

# %%
import streamlit as st

st.title("*Diabetes For Patients*")
st.markdown(
    """
    This application is used to detect the percentage of diabetes in patients from a specific hospital.
    """
)
# Out:
# 2025-01-25 13:45:27.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:45:27.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:45:27.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:45:27.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.sidebar.title("Instruction")
st.sidebar.info(
    """
    -Fill the input fields with your data
    -Click on Predict the risk to see the results
    -This app is informational only
    """
)
# Out:
# 2025-01-25 13:48:37.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:48:37.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:48:37.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:48:37.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())

# %%
import streamlit as st

# Input fields
st.subheader("Enter your details")

Pregnancies = st.number_input("Pregnancies", min_value=0, max_value=16, step=1)
Glucose = st.number_input("Glucose", min_value=74, max_value=200, value=100)
BloodPressure = st.number_input("BloodPressure", min_value=30, max_value=130, value=80)
SkinThickness = st.number_input("SkinThickness", min_value=0, max_value=100, value=20)
Insulin = st.number_input("Insulin", min_value=0, max_value=200, value=50)
BMI = st.number_input("BMI", min_value=14.0, max_value=60.0, value=25.0)
DiabetesPedigreeFunction = st.number_input("DiabetesPedigreeFunction", min_value=0.0, max_value=2.5, value=0.5)
Age = st.number_input("Age", min_value=10, max_value=100, step=1)
# Out:
# 2025-01-25 13:56:39.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:56:39.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:56:39.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:56:39.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:56:39.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:56:39.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 13:56:39.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import numpy as np
import streamlit as st

# Example scaled_inputs transformation (replace with actual preprocessing if needed)
inputs = [[Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age]]
scaled_inputs = np.array(inputs)  # Convert inputs to NumPy array (apply scaling if needed)

if st.button("Predict the risk"):
    result = model.predict(scaled_inputs)  # Use the appropriate scaled input
    if result[0] == 0:
        st.success("You are at low risk for diabetes. Keep practicing healthy habits!")
    else:
        st.warning("You are at high risk for diabetes. Consult a doctor immediately!")

# Sidebar for Model Performance
st.sidebar.title("Model Performance")
st.sidebar.markdown(
    """
    - *Accuracy:* Display the model's accuracy here.
    - *F1 Score:* Display the F1 score here.
    - *Confusion Matrix:* Describe or visualize the confusion matrix here.
    - *Classification Report:* Add the classification report here.
    - *ROC Curve:* Visualize the ROC curve here.
    - *PR Curve:* Visualize the Precision-Recall curve here.
    """
)
# Out:
# 2025-01-25 14:15:56.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:15:56.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:15:56.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:15:56.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:15:56.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:15:56.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:15:56.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.markdown("---")
st.caption("App Directed By Tarek Seif")
# Out:
# 2025-01-25 14:17:57.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:17:57.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:17:57.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-25 14:17:57.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
